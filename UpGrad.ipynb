# %%
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

# %%
# import sys
# !{sys.executable} -m pip install jupyterthemes

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("D:\\bank-full.csv")

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no

# %%
import seaborn as sns

# %%
sns.pairplot(df,hue="y",palette="husl")

# %%
#avg age of people with certain profession and Education
sns.relplot(x="job", y="age",data=df,hue="education",height=5, aspect=3, facet_kws=dict(sharex=False),
            kind="line", legend="full")

# %%
sns.relplot(x="job", y="balance",data=df,hue="y",height=5, aspect=3, facet_kws=dict(sharex=False),
            kind="line", legend="full")

# %%
sns.relplot(x="job", y="age",data=df,hue="y",height=5, aspect=3, facet_kws=dict(sharex=False),
            legend="full")

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
with sns.color_palette("BuGn"):
    sns.countplot(data=df,x="education",hue="y")

# %%
with sns.color_palette("BrBG"):
    sns.countplot(data=df,x="contact",hue="y")

# %%
sns.countplot(data=df,x="poutcome",hue="y")

# %%
sns.distplot(df[["pdays"]])

# %%
#converting String to Numeric Values
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
df[["job"]] = lb.fit_transform(np.array(df[["job"]]))
df[["marital"]] = lb.fit_transform(np.array(df[["marital"]]))
df[["education"]] = lb.fit_transform(np.array(df[["education"]]))
df[["default"]] = lb.fit_transform(np.array(df[["default"]]))
df[["housing"]] = lb.fit_transform(np.array(df[["housing"]]))
df[["loan"]] = lb.fit_transform(np.array(df[["loan"]]))
df[["contact"]] = lb.fit_transform(np.array(df[["contact"]]))
df[["day"]] = lb.fit_transform(np.array(df[["day"]]))
df[["month"]] = lb.fit_transform(np.array(df[["month"]]))
df[["poutcome"]] = lb.fit_transform(np.array(df[["poutcome"]]))
df[["y"]] = lb.fit_transform(np.array(df[["y"]]))
import warnings
warnings.filterwarnings("ignore")

# %%
df.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0    4      8       261         1     -1         0         3  0
# 1    4      8       151         1     -1         0         3  0
# 2    4      8        76         1     -1         0         3  0
# 3    4      8        92         1     -1         0         3  0
# 4    4      8       198         1     -1         0         3  0

# %%
#dropping day Columns
df = df.drop(["day"], axis=1)

# %%
df.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   58    4        1          2        0     2143        1     0        2
# 1   44    9        2          1        0       29        1     0        2
# 2   33    2        1          1        0        2        1     1        2
# 3   47    1        1          3        0     1506        1     0        2
# 4   33   11        2          3        0        1        0     0        2
#
#    month  duration  campaign  pdays  previous  poutcome  y
# 0      8       261         1     -1         0         3  0
# 1      8       151         1     -1         0         3  0
# 2      8        76         1     -1         0         3  0
# 3      8        92         1     -1         0         3  0
# 4      8       198         1     -1         0         3  0

# %%
from sklearn import model_selection
from pandas.plotting import scatter_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
models = [("LR",LogisticRegression()),("KNN",KNeighborsClassifier()),
          ("DT",DecisionTreeClassifier()),
          ("RFC",RandomForestClassifier(n_estimators=400,min_samples_split=4)),("xg",XGBClassifier())]

# %%
x = df.iloc[:,:15]
y = df.iloc[:,15:16]

# %%
# Standardising the data.
from sklearn.preprocessing import scale

for i in range(0,15):
    x.iloc[:,i] = scale(x.iloc[:,i])

# %%
# splitting the Data into Training and Test Data
seed = 7
validation_size = 0.2
x_train,x_test,y_train,y_test = model_selection.train_test_split(x,y,test_size = validation_size, random_state = seed)

# %%
x.head()
# Out:
#         age       job   marital  education  default   balance   housing  \
# 0  1.606965 -0.103820 -0.275762   1.036362 -0.13549  0.256419  0.893915
# 1  0.288529  1.424008  1.368372  -0.300556 -0.13549 -0.437895  0.893915
# 2 -0.747384 -0.714951 -0.275762  -0.300556 -0.13549 -0.446762  0.893915
# 3  0.571051 -1.020516 -0.275762   2.373280 -0.13549  0.047205  0.893915
# 4 -0.747384  2.035139  1.368372   2.373280 -0.13549 -0.447091 -1.118674
#
#        loan   contact     month  duration  campaign     pdays  previous  \
# 0 -0.436803  1.514306  0.823773  0.011016 -0.569351 -0.411453  -0.25194
# 1 -0.436803  1.514306  0.823773 -0.416127 -0.569351 -0.411453  -0.25194
# 2  2.289359  1.514306  0.823773 -0.707361 -0.569351 -0.411453  -0.25194
# 3 -0.436803  1.514306  0.823773 -0.645231 -0.569351 -0.411453  -0.25194
# 4 -0.436803  1.514306  0.823773 -0.233620 -0.569351 -0.411453  -0.25194
#
#    poutcome
# 0  0.444898
# 1  0.444898
# 2  0.444898
# 3  0.444898
# 4  0.444898

# %%
for name,model in models:
    k_fold = model_selection.KFold(n_splits=10)
    cv_results = model_selection.cross_val_score(model,x_train,y_train,cv=k_fold,scoring="accuracy")
    msg = "%s:%f, %f" % (name,cv_results.mean(),cv_results.std())
    print(msg)
# Out:
# LR:0.888852, 0.005585
# KNN:0.891645, 0.004261
# DT:0.868696, 0.004542
# RFC:0.903976, 0.005919
# xg:0.900963, 0.006268

# %%
# predicting With Different Machine learning Model
for name,model in models:
    print(name)
    model.fit(x_train,y_train)                   #model Fit
    predictions = model.predict(x_test)
    print(accuracy_score(y_test,predictions))    #printing Accuracy Score 
    print(classification_report(y_test,predictions))
# Out:
# LR
# 0.8974897710936636
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      8027
#            1       0.61      0.24      0.34      1016
#
#    micro avg       0.90      0.90      0.90      9043
#    macro avg       0.76      0.61      0.64      9043
# weighted avg       0.88      0.90      0.88      9043
#
# KNN
# 0.8971580227800509
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94      8027
#            1       0.57      0.35      0.43      1016
#
#    micro avg       0.90      0.90      0.90      9043
#    macro avg       0.75      0.66      0.69      9043
# weighted avg       0.88      0.90      0.89      9043
#
# DT
# 0.8719451509454826
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93      8027
#            1       0.44      0.50      0.47      1016
#
#    micro avg       0.87      0.87      0.87      9043
# ...

# %%
# we can see Accuracy of Xgboost is about 0.9104
# accuracy of Random Forest is about 0.9109
# we can Reduce Cost Price of marketing by using Model we Trained
# we will test our data by the model Generated above to reduce cost price and increase prospects
